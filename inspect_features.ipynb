# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from glob import glob
import imblearn
from collections import Counter

# %%
data = pd.read_csv('../tables/data_all.csv')
data
# Out:
#                Teff       age        Lx        Rs       loc         Teq  \
# 0       3252.895461  5.008207  0.000005  0.210784  0.016239  545.427269
# 1       3546.034985  4.989730  0.000003  0.202281  0.015047  527.637939
# 2       3229.023196  5.003891  0.000004  0.207189  0.015744  519.483858
# 3       3072.870969  5.006503  0.000004  0.220353  0.015021  525.917339
# 4       3185.925252  4.988552  0.000004  0.214874  0.015777  526.933313
# ...             ...       ...       ...       ...       ...         ...
# 149995  2544.859297  7.471444  0.000354  0.119351  0.038455  184.189272
# 149996  2555.444817  9.826661  0.000401  0.121573  0.038416  199.799745
# 149997  2595.714241  7.059310  0.000325  0.117958  0.038727  208.021856
# 149998  2566.269606  8.714504  0.000356  0.117075  0.038559  176.432263
# 149999  2545.250993  3.766995  0.000264  0.118984  0.038673  200.396196
#
#           Bfield       rho        Rp     Psurf       WMF       Tsurf  \
# ...

# %%
plt.figure(figsize=(15,5))
sns.histplot(data=data, x="Teff", hue="Life_4comb", binwidth=500, multiple="dodge", stat="probability", shrink=.8, palette="tab10")

# %%
plt.figure(figsize=(15,5))
sns.histplot(data=data, x="age", hue="Life_4comb", binwidth=1., multiple="dodge", stat="probability", shrink=.8, palette="tab10")

# %%
plt.figure(figsize=(15,5))
sns.histplot(data=data, x="Lx", hue="Life_4comb", binwidth=1e-4, multiple="dodge", stat="probability", shrink=.8, palette="tab10")

# %%
plt.figure(figsize=(15,5))
sns.histplot(data=data, x="Rs", hue="Life_4comb", binwidth=0.2, multiple="dodge", stat="probability", shrink=.8, palette="tab10")

# %%
plt.figure(figsize=(15,5))
sns.histplot(data=data, x="loc", hue="Life_4comb", binwidth=0.5, multiple="dodge", stat="probability", shrink=.8, palette="tab10")

# %%
plt.figure(figsize=(15,5))
sns.histplot(data=data, x="Teq", hue="Life_4comb", binwidth=50, multiple="dodge", stat="probability", shrink=.8, palette="tab10")

# %%
plt.figure(figsize=(15,5))
sns.histplot(data=data, x="Bfield", hue="Life_4comb", binwidth=0.1, multiple="dodge", stat="probability", shrink=.8, palette="tab10")

# %%
plt.figure(figsize=(15,5))
sns.histplot(data=data, x="rho", hue="Life_4comb", binwidth=1, multiple="dodge", stat="probability", shrink=.8, palette="tab10")

# %%
plt.figure(figsize=(15,5))
sns.histplot(data=data, x="Rp", hue="Life_4comb", binwidth=0.2, multiple="dodge", stat="probability", shrink=.8, palette="tab10")

# %%
plt.figure(figsize=(15,5))
sns.histplot(data=data, x="Psurf", hue="Life_4comb", binwidth=2, multiple="dodge", stat="probability", shrink=.8, palette="tab10")

# %%
plt.figure(figsize=(15,5))
sns.histplot(data=data, x="Psurf", hue="Life_4comb", binwidth=0.1, multiple="dodge", stat="probability", shrink=.8, palette="tab10")
plt.xlim([0,2])
# Out:
# (0, 2)

# %%
plt.figure(figsize=(15,5))
sns.histplot(data=data, x="WMF", hue="Life_4comb", binwidth=0.1, multiple="dodge", stat="probability", shrink=.8, palette="tab10")

# %%
plt.figure(figsize=(15,5))
sns.histplot(data=data, x="Tsurf", hue="Life_4comb", binwidth=100, multiple="dodge", stat="probability", shrink=.8, palette="tab10")

# %%
plt.figure(figsize=(15,5))
sns.histplot(data=data, x="sal", hue="Life_4comb", binwidth=3, multiple="dodge", stat="probability", shrink=.8, palette="tab10")

# %%
plt.figure(figsize=(15,5))
sns.histplot(data=data, x="pH", hue="Life_4comb", binwidth=1, multiple="dodge", stat="probability", shrink=.8, palette="tab10")

# %%
plt.figure(figsize=(15,5))
sns.histplot(data=data, x="Aw", hue="Life_4comb", binwidth=0.1, multiple="dodge", stat="probability", shrink=.8, palette="tab10")
